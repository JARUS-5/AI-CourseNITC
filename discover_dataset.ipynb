# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv("./datasets/Concrete_Data_Yeh.csv")

# %%
df.describe()
# Out:
#             cement         slag       flyash        water  superplasticizer  \
# count  1030.000000  1030.000000  1030.000000  1030.000000       1030.000000
# mean    281.167864    73.895825    54.188350   181.567282          6.204660
# std     104.506364    86.279342    63.997004    21.354219          5.973841
# min     102.000000     0.000000     0.000000   121.800000          0.000000
# 25%     192.375000     0.000000     0.000000   164.900000          0.000000
# 50%     272.900000    22.000000     0.000000   185.000000          6.400000
# 75%     350.000000   142.950000   118.300000   192.000000         10.200000
# max     540.000000   359.400000   200.100000   247.000000         32.200000
#
#        coarseaggregate  fineaggregate          age        csMPa
# count      1030.000000    1030.000000  1030.000000  1030.000000
# mean        972.918932     773.580485    45.662136    35.817961
# std          77.753954      80.175980    63.169912    16.705742
# ...

# %%
X = df["cement"]
Y = df["csMPa"]

# %%
plt.scatter(X,Y)
plt.show()

# %%
water = df["water"]

# %%
plt.scatter(water,Y)
plt.show()

# %%
X.unique().shape
# Out:
# (278,)

# %%
X.unique()
# Out:
# array([540. , 332.5, 198.6, 266. , 380. , 475. , 427.5, 190. , 304. ,
#        139.6, 342. , 237.5, 349. , 310. , 485. , 374. , 313.3, 425. ,
#        375. , 469. , 388.6, 531.3, 318.8, 401.8, 362.6, 323.7, 379.5,
#        286.3, 439. , 389.9, 337.9, 222.4, 233.8, 194.7, 190.7, 212.1,
#        230. , 190.3, 166.1, 168. , 213.7, 213.8, 229.7, 238.1, 250. ,
#        212.5, 212.6, 212. , 231.8, 251.4, 181.4, 182. , 168.9, 290.4,
#        277.1, 295.7, 251.8, 249.1, 252.3, 246.8, 275.1, 297.2, 213.5,
#        277.2, 218.2, 214.9, 218.9, 376. , 500. , 315. , 505. , 451. ,
#        516. , 520. , 528. , 385. , 500.1, 450.1, 397. , 333. , 334. ,
#        405. , 200. , 145. , 160. , 234. , 285. , 356. , 275. , 165. ,
#        178. , 167.4, 172.4, 173.5, 167. , 173.8, 446. , 387. , 355. ,
#        491. , 424. , 202. , 284. , 359. , 436. , 289. , 393. , 480. ,
#        255. , 158.8, 239.6, 238.2, 181.9, 193.5, 255.5, 272.8, 220.8,
# ...

# %%
sdf = df[df["cement"]==159]

# %%
sdf
# Out:
#      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 838   159.0  149.0   116.0  175.0              15.0            953.0
# 871   159.0  187.0     0.0  176.0              11.0            990.0
# 930   159.0  209.0   161.0  201.0               7.0            848.0
#
#      fineaggregate  age  csMPa
# 838          720.0   28  27.68
# 871          789.0   28  32.76
# 930          669.0   28  30.88

# %%
water.unique().shape
# Out:
# (195,)

# %%
a = np.sort(water.unique())

# %%
a
# Out:
# array([121.8, 126.6, 127. , 127.3, 137.8, 140. , 140.8, 141.8, 142. ,
#        143.3, 144.7, 145. , 145.9, 146. , 146.1, 146.3, 147.4, 151. ,
#        151.4, 153.5, 153.9, 154. , 154.6, 154.8, 155.6, 155.7, 156.8,
#        157. , 157.9, 158. , 158.1, 158.3, 158.4, 158.5, 159. , 159.2,
#        159.3, 159.4, 159.5, 160. , 160.6, 160.7, 161.9, 162. , 162.1,
#        163. , 163.6, 163.8, 164. , 164.8, 164.9, 165. , 165.6, 166.6,
#        166.7, 167. , 167.5, 167.8, 167.9, 168. , 168.1, 168.3, 168.4,
#        169.6, 169.9, 170. , 170.1, 170.2, 170.6, 171. , 171.2, 171.5,
#        171.6, 172. , 172.3, 172.4, 173. , 173.5, 173.8, 174. , 174.8,
#        174.9, 175. , 175.1, 175.5, 175.6, 175.8, 176. , 176.5, 177. ,
#        177.4, 177.6, 177.9, 178. , 178.1, 178.5, 178.8, 178.9, 179. ,
#        179.6, 179.9, 180. , 180.2, 180.3, 180.8, 181. , 181.1, 181.2,
#        181.4, 181.6, 181.7, 181.9, 182. , 182.5, 182.9, 183. , 183.2,
# ...

# %%
wdf = df[df["water"]==228]

# %%
wdf.sort_values(["slag","fineaggregate","cement","age"])
# Out:
#      cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 29    475.0    0.0     0.0  228.0               0.0            932.0
# 9     475.0    0.0     0.0  228.0               0.0            932.0
# 38    475.0    0.0     0.0  228.0               0.0            932.0
# 19    475.0    0.0     0.0  228.0               0.0            932.0
# 33    475.0    0.0     0.0  228.0               0.0            932.0
# 56    475.0    0.0     0.0  228.0               0.0            932.0
# 15    380.0    0.0     0.0  228.0               0.0            932.0
# 43    380.0    0.0     0.0  228.0               0.0            932.0
# 25    380.0    0.0     0.0  228.0               0.0            932.0
# 24    380.0    0.0     0.0  228.0               0.0            932.0
# 40    342.0   38.0     0.0  228.0               0.0            932.0
# 27    342.0   38.0     0.0  228.0               0.0            932.0
# 65    342.0   38.0     0.0  228.0               0.0            932.0
# ...

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
np.__version__
# Out:
# '1.16.2'
